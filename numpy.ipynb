# %%
import numpy as np

# %%
# Array com uma sequência de números 9similar ao range()
sequencia = np.arange(0, 10, 2) # Início, fim (exclusivo), Passo
print("\nSequência (arange):", sequencia)
# Out:
# Sequência (arange): [0 2 4 6 8]

# %%
# Valores linearmente espaçados
espacados = np.linspace(0, 1, 5) #5 valores entre 0 e 1
print("\nLinspace:", espacados)
# Out:
# Linspace: [0.   0.25 0.5  0.75 1.  ]

# %% [markdown]
# #### 3. Inspecionando Arrays
# É crucial saber o tamanho e o formato dos seus dados, especialmente ao preparar datasets para mineração de dados

# %%
print("Formato (shape):", matriz.shape) #(linha, colunas)
print("Dimensões (ndim):", matriz.ndim) # Número de dimensões
print("Tamanho total (size):", matriz.size) # Total de elementos
print("Tipo de dado (dtype):", matriz.dtype) #Tipo dos elementos

# Typecasting é o nome do que o python faz com o tipo das variáveis, para descobrir qual o tipo
# É possível tipar no python, só não é obrigatório - é recomendável tipar

# %% [markdown]
# Numpy permite que façamos operações matemáticas com arrays de forma simples, como (matriz a + matriz b)
